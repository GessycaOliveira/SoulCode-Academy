# %% [markdown]
# <a href="https://colab.research.google.com/github/GessycaOliveira/SoulCode-Academy/blob/main/Conteudos_S4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FUNDAMENTOS DE PYTHON
#
# Escola: SoulCode Academy
#
# Curso: Bootcamp Analista de Dados - Martech - AD2
#
# Período: Semana 4
#
# Professores: Franciane Rodrigues e Douglas Ribeiro
#
# Aluna: Gessyca de Oliveira Cunha

# %% [markdown]
# # Conteúdos:
# * Conceitos básicos
# * Comentários e tipos básicos de dados
# * Variáveis
# * Operadores matemáticos

# %% [markdown]
# ## Conceitos básicos

# %% [markdown]
# > Lógica de programação: É a estruturação de conceitos e regras que orientam a execução do algoritmo.
#
# > Algoritmo: É a receita, ou seja, os comandos em um passo a passo, claro e logico que conduzem as ações para a resolução de um problema ou para atingir determinado objetivo.
#
# > Programação: É a implementação do algoritmo.

# %% [markdown]
# ## Comentários e tipos básicos de dados

# %% [markdown]
# ### Comentários

# %%
print('Olá, Mundo!') # Usando aspas simples
print("Olá, Mundo!") # Usando aspas duplas
# Diferença entre elas: preferência de quem usa.
# Out:
# Olá, Mundo!
# Olá, Mundo!

# %%
# Isto é um comentário simples
''' Este é um comentário grande
 de aspas simples 3x.'''
""" Este é um comentário grande
 de aspas duplas 3x. """

# %% [markdown]
# ### Tipos de dados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Estamos escrevendo nossos dados pessoais
print(25)                 #int
print(1.65)               #float
print('Gessyca')          #str com aspas simples
print("Oliveira")         #str com aspas duplas
print(False)              #bool

# %% [markdown]
# ### **RESUMO**
#
# Os comentários são como notas que você deixa para que você ou outra pessoa possa ler e ajuda documentar o seu código.
#
# Comando print: é uma função de saída utilizada em várias linguagens de programação para exibir mensagens ou valores na tela do computador.
#
# \n: usado para criar quebras de linha em um texto
#
# Tipos de dados no Python mais usados são: **int, float, str, bool**
#
# int e float: dados quantitativos
#
# str: dados categóricos

# %% [markdown]
# ## Variáveis

# %%
# Imprimindo valores e descrevendo seus tipos nas variáveis
print(25)                 #int
print(1.60)               #float
print('Gessyca')          #str com aspas simples
print("Oliveira")         #str com aspas duplas
print(False)              #bool
# Out:
# 25
# 1.6
# Gessyca
# Oliveira
# False

# %%
# Declarando as variáveis (sem imprimir)
idade = 25
altura = 1.60
nome = 'Gessyca'
sobrenome = "Oliveira"
filhos = False

# %%
# Imprimindo os valores que foram declarados acima
print(idade)
print(altura)
print(nome)
print(sobrenome)
print(filhos)
# Out:
# 25
# 1.6
# Gessyca
# Oliveira
# False

# %%
# Imprimir na tela usando o nome da variável (mostra só a última)
idade
altura
# Out:
# 1.6

# %%
''' Imprimir na tela usando apenas um comando print para chamar todas as variáveis
todos ficarão juntos na mesma linha '''
print(idade, altura, nome, sobrenome, filhos)
# Out:
# 25 1.6 Gessyca Oliveira False

# %%
# Comando type serve para checarmos o tipo de dado que a variável está declarada
type(idade)
# Out:
# int

# %%
# Checando o tipo de variável usando os comandos print e type juntos
print(type(idade))
print(type(altura))
print(type(nome))
print(type(sobrenome))
print(type(filhos))
# Não mostra a variável, apenas o tipo dela.
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
# Armazenamento strings e número
nome_completo = 'Gessyca Oliveira'
numero_favorito = "4"

# %%
# Checando a variável numero_favorito
print(type(numero_favorito))
# se o numero estiver entre aspas ele se transforma numa string (ex. CPF e ID)
# Out:
# <class 'str'>

# %%
# Primeiro nome do nosso código
nome
# Out:
# 'Gessyca'

# %%
nome = 'Sara'

# %%
# Atualização da variável "nome"
# Sempre a última alteração será a válida
nome
# Out:
# 'Sara'

# %%
# Declarando multiplicas variáveis de forma contraída, ficarão salvas de acordo com a ordem
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(z)
print(y)
# Out:
# Orange
# Cherry
# Banana

# %%
# Declarando o mesmo valor em variáveis diferentes:
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
# Declarando variáveis salvas em uma lista
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)

# %% [markdown]
# ### **RESUMO**
# *  **Variáveis** permitem salvar valores na memória usando um nome que atribuímos
# * Declaramos um nome no lado esquerdo do operador igual (“=”), e no lado direito, atribuir o valor que queremos salvar para usar mais tarde.
# * Como ler: Declaramos a variável "a" ao valor do "2" do tipo int
# * a = 2
# * Como ler: Declaramos a variável "b" ao valor do "10.953" do tipo float
# * b = 10.953
# * Como ler: A variável "a" recebe valor 2 do tipo int
# * a = 2
# * Como ler: A variável "b" recebe valor 10.953 do tipo float
# * b = 10.953
# * É possível usar os dois comandos print e type juntos
# * Atenção: Número pode ser string
#
# **Regras para nomes de variáveis**
# * Deve começar com uma letra (maíuscula ou minúscula) ou subcrito(_).
# * Nunca pode começar com um número.
# * Pode conter letras maiúsculas, minúsculas, números e subscrito.
# * Não pode-se utilizar como parte do nome de uma variável:
# { ( + - * / \ ; . , ?
# * Letras maiúsculas e minúsculas são diferentes:
# casa = 4
# Casa = 4

# %% [markdown]
# ## **Conversão de variáveis**

# %% [markdown]
# ### Int > Float

# %%
# Conversão de int para float
num_int = 10 #Variável inteira
num_float = float(num_int)       # Declarar nova variável = tipo de conversão |int|float|str| (nome da variável que será transformada)
# Checando a conversão
print(type(num_int), type (num_float))
print(num_float)
# Out:
# <class 'int'> <class 'float'>
# 10.0

# %% [markdown]
# ### Int > String

# %%
# Conversão de int para string
num_int = 10
num_str = str(num_int)
# Checando a conversão
print(type(num_int),  type(num_str))
print(num_str)
# Out:
# <class 'int'> <class 'str'>
# 10

# %% [markdown]
# ### String > Float

# %%
# Conversão de str para float
num_str = '3'
num_flt = float(num_str)
# Checando a conversão
print ( type (num_str), type(num_flt))
print(num_flt)
# Out:
# <class 'str'> <class 'float'>
# 3.0

# %% [markdown]
# ### Complex > String

# %%
#converter complexo para string:
z = 1j   # complexo
c = complex(z)
b = str(z)
# Conferindo...
print(type(b))
print(b)
# Out:
# <class 'str'>
# 1j

# %% [markdown]
# ## **Operadores Matemáticos**

# %% [markdown]
# ### Operadores básicos

# %%
soma = 3 + 2
sub = 3 - 2
mult = 3 * 2
div = 7 / 2
idiv = 7 // 2   # Parte inteira da divisão (//) Ex.: Encontre e guarde a parte inteira da divisão de 3 por 2
rdiv = 7 % 2     # Resto da divisão (//) Ex.: Encontre e guarde o resto da divisão de 3 por 2
pot = 3 ** 2     # Potenciação (**) Ex.: eleve 3 a 2
print('soma:',soma, 'sub:', sub, 'mult:', mult, 'div:', div, 'parte inteira div:', idiv, 'resto da div:', rdiv, 'potenciação:', pot)
# Out:
# soma: 5 sub: 1 mult: 6 div: 3.5 parte inteira div: 3 resto da div: 1 potenciação: 9

# %%
# Melhorando a visualização dos prints com f-string
print(f'O resultado da soma de 3 com 2 é: {soma}')
print(f'O resultado da subtração de 3 com 2 é: {sub}')
print(f'O resultado da multiplicação de 3 com 2 é: {mult}')
print(f'O resultado da divisão de 3 com 2 é: {div}')
print(f'A parte inteira da divisão de 3 com 2 é: {idiv}')
print(f'O resto da divisão de 3 com 2 é: {rdiv}')
print(f'O resultado da potenciação de 3 com 2 é: {pot}')
# Out:
# O resultado da soma de 3 com 2 é: 5
# O resultado da subtração de 3 com 2 é: 1
# O resultado da multiplicação de 3 com 2 é: 6
# O resultado da divisão de 3 com 2 é: 1.5
# A parte inteira da divisão de 3 com 2 é: 1
# O resto da divisão de 3 com 2 é: 1
# O resultado da potenciação de 3 com 2 é: 9

# %% [markdown]
# #### Adição

# %%
# Adição
n1 = 5.887
n2 = 7.15
soma = n1 + n2
# Modos de apresentação
print(soma)
print('A soma é:', soma)
print(f"A soma dos números é {soma:.2f}")
print(n1 + n2)
n1+n2

# %% [markdown]
# #### Subtração

# %%
# Subtração
a1 = 154.587
a2 = 10.58
sub = a1 - a2
# Conferindo:
print(sub)

# %% [markdown]
# #### Multiplicação

# %%
# Multiplicação
b1 = 3.5
multi = b1 * 3
# Conferindo:
print('A multiplicação é: ', round(multi,2))

# %% [markdown]
# #### Divisão

# %%
# Divisão
x1 = 10
x2 = 5
div = x1/x2
# Conferindo:
print(f'A multiplicação dos números é {div:.2f}')

# %% [markdown]
# #### RESUMO

# %% [markdown]
# ---
#
#
# Operadores
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Operações de compração com booleanos

# %%
# (==) verifica se dois valores são iguais (retorna True ou False)
# Ex.: compare se 2 é igual a 3
a = 3 == 2

# str é diferente de int
b = 3 == '3' # Verificando se ambos são iguais
c = 3 != '3' # verificando se são diferentes
print(a, b, c)
# Out:
# False False True

# %%
# Verificando se número int 3 é igual ao float 3.0
a = 3 # Atribuição do valor 3 (tipo int) para variável A
b = 3.0 # Atribuição do valor 3.0 (tipo float) para a variável B
teste1 = a == b # Fazendo o teste de igualdade de A com B e guadando na variável teste 1
print(teste1) # imprimindo o valor da variável teste1
# Out:
# True

# %%
# Testando sensibilidade com letras maiúscula e minúscula
teste2= 'gessyca' == 'Gessyca'
print(teste2)
# Out:
# False

# %%
# (>) verifica se um valor é maior que outro (retorna True ou False)
# Ex.: compare se 3 é maior que 2
teste4 = 3 > 2
print(teste4)

# (>=) verifica se um valor é maior ou igual ao outro (retorna True ou False)
# Ex.: compare se 3 é maior ou igual que 3
teste5 = 3 >= 3
print(teste5)
# Out:
# True
# True

# %%
# (<) verifica se um valor é menor que outro (retorna True ou False)
# Ex.: compare se 2 é menor que 2
teste6 = 2 < 2
print(teste6)

# (<=) verifica se um valor é menor ou igual ao outro (retorna True ou False)
# Ex.: compare se 2 é menor ou igual a 2
teste7 = 3 <= 3
print(teste7)
# Out:
# False
# True

# %% [markdown]
# #### RESUMO

# %% [markdown]
# ---
#
#
# Operadores de comparação
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Operadores de atribuição

# %%
# Atribuição direta (=) atribui ao lado esquedo do sinal um valor que está ao lado direito do sinal
nome = 'gessyca'
peso_kg = 65
altura_m = 1.60

# %% [markdown]
# #### +=

# %%
# Atribuição de incremento (+=), equivale a x = x + y
# Ex.: crie uma variável T que receba o número inteiro, e depois acrescente o valor 1 para essa variável
t = 3
t += 1 # T é igual a ele mesmo + 1 (t + 1)
# O igual significa que a variável 't' agora assumirá o novo valor da soma.
print(t)
t += t + 1 # T é igual a ele mesmo + 1 (t + t + 1)
print(t)
# Out:
# 4
# 9

# %% [markdown]
# #### -=

# %%
# Atribuição de decretamento (-=) equivale a x = x - y (equivale a uma variável X que já existe recebendo ela mesma - outro valor)
# Ex.: crie uma variável Z que receba o número inteiro 5, e depois diminua 2 para essa variável
z = 5
z -= 2
print(f'z é igual {z}')
#float
g = 5
g -= 2.89
print(f'g é igual {g}')
# Out:
# z é igual 3
# g é igual 2.11

# %% [markdown]
# ### Operadores lógicos

# %% [markdown]
# #### and

# %%
# (and) Retorna verdadeiro somente se todas as condições de uma comparação forem satisfeitas
# Exemplo:
teste8 = 3 >= 2 and 3 != 2 and 3 < 4
print(f'3 >= 2 and 3 != 2 and 3 < 4 é: {teste8}')
# (&) Retorna verdadeiro somente se todas as condições de uma comparação forem satisfeitas
# Exemplo:
teste9 = (3 <= 2) & (3 != 2) & (3 < 4) #bitwise
#           F           V         V
print(f'(3 <= 2) & (3 != 2) & (3 < 4) é: {teste9}')
# Out:
# 3 >= 2 and 3 != 2 and 3 < 4 é: True
# (3 <= 2) & (3 != 2) & (3 < 4) é: False

# %% [markdown]
# #### or

# %%
# (or) Retorna verdadeiro se pelo menos um dos elementos for verdadeiro
# Exemplo:
teste10 = 3 >= 2 or 3 == 2 or 3 > 4
teste15 = (3 >= 2) | (3 == 2) | (3 > 4)
print(f'3 >= 2 or 3 == 2 or 3 > 43 >= 2 or 3 == 2 or 3 > 4 é: {teste10}')
# Out:
# 3 >= 2 or 3 == 2 or 3 > 43 >= 2 or 3 == 2 or 3 > 4 é: True

# %% [markdown]
# #### not

# %%
# (not) Inverte verdadeiro com Falso
# Exemplo:
teste11 = not(teste10)
print(f'not(3 >= 2 or 3 == 2 or 3 > 4) é: {teste11}')
teste12 = not(teste9)
print(f'not((3 <= 2) & (3 != 2) & (3 < 4)) é: {teste12}')
teste13 = (not(3 <= 2)) & (not(3 == 2)) & (3 < 4) # invertendo o resultado da primeira sentença e da segunda sentença
#               V                 V            V
print(f'((not(3 <= 2))) & (not(3 == 2)) & (3 < 4) é: {teste13}')
teste14 = not((3 >= 2) & (3 != 2) & (3 < 4)) # invertendo o resultado da comparação de todas as sentenças
#                 V         V           V
print(f'not((3 >= 2) & (3 != 2) & (3 < 4)) é: {teste14}')
print(teste15)
# Out:
# not(3 >= 2 or 3 == 2 or 3 > 4) é: False
# not((3 <= 2) & (3 != 2) & (3 < 4)) é: True
# ((not(3 <= 2))) & (not(3 == 2)) & (3 < 4) é: True
# not((3 >= 2) & (3 != 2) & (3 < 4)) é: False
# True

# %% [markdown]
# #### RESUMO

# %% [markdown]
# ---
#
#
# Operadores logicos
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Operadores de identidade

# %% [markdown]
# #### is

# %%
# (is) compara se um objeto é igual ao outro em relação ao valor e o tipo
h = 3
p = 3
teste16 = p == h
print(f'p == h é: {teste16}')
teste17 = p is h
print(f'p is h é: {teste17}')
m = 3
n = 3.0
teste18 = m == n
print(f'm == n é: {teste18}')
teste19 = m is n
print(f'm is n é: {teste19}')
print(type(m))
print(type(n))
# Out:
# p == h é: True
# p is h é: True
# m == n é: True
# m is n é: False
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #### is not

# %%
# (is not) compara se um objeto é diferente do outro em relação ao valor e o tipo
x = 3
y = 4
teste20 = x != y
print(f'x != y é: {teste20}')
teste21 = x is not y
print(f'x is not y é: {teste21}')
o = 3
s = 3.0
teste22 = o != s
print(f'o != s é: {teste22}')
teste23 = o is not s
print(f'o is not s é: {teste23}')
print(type(o))
print(type(s))

# %% [markdown]
# #### RESUMO

# %% [markdown]
# Operadores de identidade

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Operadores de associação

# %% [markdown]
# #### in

# %%
# (in) Retorna verdadeiro se um caracter ou sequencia de caracteres for encontrado dentro de uma string
# Exemplo:
nome = 'daniela'
teste24 = 'dani' in nome
print(f'daniela contém dani: {teste24}')
# Out:
# daniela contém dani: True

# %% [markdown]
# #### in not

# %%
# (not in) Retorna verdadeiro se um caracter ou sequencia de caracteres NÃO for encontrado dentro de uma string
teste25 = 'Dani' not in nome
print(f'daniela não contém Dani: {teste25}')
# Out:
# daniela não contém Dani: True

# %% [markdown]
# #### RESUMO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Strings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
email = 'python@gmail.com'
print(email)
# Encontrando um caracter pelo índice
# Ex.: qual é o quinto caracter dessa string?
print(f'O quinto caracter dessa string é: {email[4]}')

# A contagem inicia no "zero", então o caracter que esta no índice "-1" é o "m"
print(f'O último caracter dessa string é: {email[-1]}')

# Exemplo: Quais são os caracteres que vem depois do segundo (excluindo até o segundo)
print(f'A sequencia de caracteres dessa string após o 2º índice: {email[2:]}')

# Exemplo: Quais são todos os carateres dessa string?
print(f'A sequencia todos os caracteres dessa string é: {email[:]}')

# Exemplo: buscar e imprimir todos os caracteres até o caracter de indice 4 (tudo antes)
print(f'A sequencia de caracteres dessa string até o 4º índice: {email[:4]}')

# Exemplo como acessar o último caracter da lista sem contar o tamaho dela (sem usar a função len())?
print(f'O último caracter dessa string é: {email[-1]}')
# Out:
# python@gmail.com
# O quinto caracter dessa string é: o
# O último caracter dessa string é: m
# A sequencia de caracteres dessa string após o 2º índice: thon@gmail.com
# A sequencia todos os caracteres dessa string é: python@gmail.com
# A sequencia de caracteres dessa string até o 4º índice: pyth
# O último caracter dessa string é: m

# %% [markdown]
# ## Métodos para tratamentos de strings

# %% [markdown]
# #### Transformações de caracter

# %%
a = 'exeMpLo'
print(a)
b = a.capitalize() # Deixar a primeira letra de uma string maiúscula
print(b)
c = b.casefold() # Deixa todas as letras em minúsculo
#c2 = b.lower() # Deixa todas as letras em minúsculo
print(c)
d = c.upper() # DEIXA TODAS AS LETRAS EM MAIÚSCULO
print(d)
# (title) Coloca a primeira letra de cada palavra em maiúscula
e = 'exemplo da silva'
f = e.title()
print(f)
# Out:
# exeMpLo
# Exemplo
# exemplo
# EXEMPLO
# Exemplo Da Silva

# %% [markdown]
# #### Verificações

# %% [markdown]
# ---
#
# #####count
#
#
# ---

# %%
# (count) Contar quantas vezes um caracter aparece em uma string
material = 'paralelepípedo'
qtde_p = material.count('p')
print(f'{material} tem {qtde_p} Ps')
# Out:
# paralelepípedo tem 3 Ps

# %% [markdown]
# ---
#
# #####endswith
#
#
# ---

# %%
# (endswith) Verifica se uma string termina com um caracter ou sequencia de caracteres
email = 'python@gmail.com'
teste_end = email.endswith('gmail.com')
print(teste_end)
# Out:
# True

# %% [markdown]
# ---
#
# ##### startswith
#
#
# ---

# %%
# (startswith) Verifica se uma string começa com um caracter ou sequencia de caracteres
email = 'exemplo@gmail.com'
teste_beg = email.startswith('e')
print(teste_beg)
# Out:
# True

# %% [markdown]
# ---
#
# #####isnumeric
#
#
# ---

# %%
# (isnumeric) Verifica se uma string é formada por números
rg = '123456789'
teste_rg = rg.isnumeric()
print(teste_rg)
# Out:
# True

# %% [markdown]
# ---
#
# #####isalpha
#
#
# ---

# %%
# (isalpha) Verifica se uma string é formada por letras
rg2 = 'exmplo'
teste_rg2 = rg2.isalpha()
print(teste_rg2)
# Out:
# True

# %% [markdown]
# ---
# #####isalnum
#
# ---

# %%
# (isalnum) Verifica se uma string é formada por letras ou números
rg3 = 'A1b2'
teste_rg3 = rg3.isalnum()
print(teste_rg3)
# Out:
# True

# %% [markdown]
# ---
#
# #####split
#
#
# ---

# %%
# Separar as palavras apos a vírgula (,)
a = "Este é, um, exemplo de separação atraves, da virgula."
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Este é', ' um', ' exemplo de separação atraves', ' da virgula.']

# %% [markdown]
# ---
#
# #####strip
#
# ---

# %%
# (strip) elimina caracteres indesejados de uma string, por padrão remove espaços do início e do final da string
autor = ' Exemplo '
print(len(autor))
autor = autor.strip()
print(len(autor))
# Out:
# 9
# 7

# %% [markdown]
# ---
#
# #####replace
#
# ---

# %%
# Substituir letra/caracter x por y
a = "Hello, World!"
print(a.replace("H", "RR"))

# Não substitiu números inteiros, eles terão que estar em listas
# b = (1,2,3,4)
# print(b.replace(3,7))

# (replace) substitui um caracter por outro
preco = 'R$ 10.50'
print(preco)
preco = preco.replace('.',',')
print(preco)
# Out:
# RRello, World!
# R$ 10.50
# R$ 10,50

# %% [markdown]
# ---
#
# #####format
#
# ---

# %%
# Inserindo váriaveis atraves do seu indice:
quantity = 3
item = 567
price = 49.95
order = "I want to pay {2} dollars for {0} pieces of item {1}."
print(order.format(quantity, item, price))
# Inserir sem atribuir o indice, ficará na ordem de declaração de cada variável
# quantity = 3
# itemno = 567
# price = 49.95
# myorder = "I want {} pieces of item {} for {} dollars."
# print(myorder.format(quantity, itemno, price))
# Out:
# I want to pay 49.95 dollars for 3 pieces of item 567.

# %% [markdown]
# ### RESUMO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # If, elif, else

# %% [markdown]
# ## Instrução "If"
# * A instrução "if" é usada para executar um bloco de código se uma determinada condição for verdadeira. A sintaxe geral é a seguinte:

# %%
'''
if condição:
    # bloco de código a ser executado se a condição for verdadeira
'''

# %%
idade = 19
if idade >= 18:
    print("Você é maior de idade.")
# Out:
# Você é meior de idade.

# %%
idade = 18
if idade >= 18:
    print("Você é maior de idade.")
# Out:
# Você é maior de idade.

# %%
idade = 17
if idade >= 18:
    print("Você é maior de idade.")

# %% [markdown]
# ## Instrução "else"

# %% [markdown]
# * a instrução "else" é usada em conjunto com a instrução "if" e especifica um boco de código a ser executado se a condição do "if" não for verdadeira. A sintaxe geral é a seguinte:

# %%
'''
if condição:
    #bloco de código a ser executado se a condição for verdadeira
else:
    # bloco de código a ser executado se a condição não for verdadeira
'''

# %%
idade = int(input('Digite sua idade: '))

if idade >= 18:
    print("Você é maior de idade.")
else:
    print("Você é menor de idade.")
# Out:
# Digite sua idade: 22
# Você é maior de idade.

# %% [markdown]
# ## Instrução "elif"
# * A instrução "elif" é uma abreviação de "else if" e permite testar múltiplas condições em sequência, Ela é usada quando há mais de duas possibilidades a serem consideradas. A sintaxe geral é a seguinte:

# %%
'''
if condição1:
    #bloco de código a ser executado se a condição1 for verdadeira
elif condição2:
    #bloco de código a ser executado se a condição2 for verdadeira
else:
    #bloco de código a ser executado se se nenhuma das condições anteriores for verdadeira

# %%
#nota = int(input('Digite sua nota: '))
nota = float(input('Digite sua nota: '))

if nota >= 90:
    print("Sua nota é A.")

elif nota >= 80:
    print("Sua nota é B.")

elif nota >= 70:
    print("Sua nota é C.")

else:
    print("Sua nota é D.")
# Out:
# Digite sua nota: 70.4
# Sua nota é C.

# %% [markdown]
# ## Praticando

# %% [markdown]
# Exemplo:
# *  Escreva um programa que verifique se um número digitado pelo usuário é positivo, negativo ou zero.

# %% [markdown]
# Passo a passo:
#
# 1. Solicite ao usuário que digite um número.
# 2. Armazene o número digitado em uma variável chamada "numero".
# 3. Verifique se o número digitado é igual a zero. Se sim, exiba a mensagem "O número digitado é zero."
# 4. Caso contrário, verifique se o número é maior que zero. Se sim, exiba a mensagem "O número digitado é positivo."
# 5. Se nenhuma das condições anteriores for atendida, significa que o número é negativo. Nesse caso, exiba a mensagem "O número digitado é negativo."
# 6. Encerre o programa.

# %%
numero = float(input("Digite um número: "))

if numero == 0:
    print("O número digitado é zero.")
elif numero > 0:
    print("O número digitado é positivo.")
else:
    print("O número digitado é negativo.")

# %% [markdown]
# ### RESUMO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Listas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# As lista podem ter tipos únicos:
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
# Ou podem conter vários tipos em uma unica lista:
list4 = ["abc", 34, True, 40, "male"]
# Len conta o numero de elementos de uma lista
print(len(list2))
# Tipo de variável
print(type(list4))
# Out:
# 5
# <class 'list'>

# %% [markdown]
# ## Atribuição de valores na lista

# %% [markdown]
# ---
#
# **TODOS OS DADOS SÃO FICTÍCIOS**
#
# ---

# %%
# Lista é uma estrutura que pode armazenar diversos valores sobre um determinado atributo
lista_vazia = []
noivo = ['Zé','Mané','Ana','Fran','João','Franz']
print(f'Convidados do noivo - {noivo}')
idades = [41, 47, 46, 28, 17, 50]
print(f'Idades dos convidados do noivo {idades}')
massas = [86, 74, 52, 47, 90, 110]
print(f'Massas dos convidados do noivo {massas}')
alturas = [1.68, 1.74, 1.65, 1.65, 1.80, 1.97]
print(f'Alturas (em metros) dos convidados do noivo {alturas}')
# Out:
# Convidados do noivo - ['Zé', 'Mané', 'Ana', 'Fran', 'João', 'Franz']
# Idades dos convidados do noivo [41, 47, 46, 28, 17, 50]
# Massas dos convidados do noivo [86, 74, 52, 47, 90, 110]
# Alturas (em metros) dos convidados do noivo [1.68, 1.74, 1.65, 1.65, 1.8, 1.97]

# %%
print(f'Idades dos convidados do noivo {idades}')
# Out:
# Idades dos convidados do noivo [41, 47, 46, 28, 17, 50]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Acessando elementos pelo índice

# %% [markdown]
# ---
#
# Criando sublista
#
# ---

# %%
# Acessando um elemento específico da lista a partir do seu índice
print(f'A convidada de honra é {noivo[3]}')
# Cria uma sublista com apenas os os três primeiros elementos da lita noivo
sublista = noivo[:3]
print(sublista)
p_u = [noivo[0], noivo[-1]] # Toda a lista de convidados
print(f'O primeiro convidado é {p_u[0]} e o último convidado é {p_u[-1]}') # Trazendo so os convidades dos indices 0 e -1
print(f'{noivo}') # Lista inicial noivo esta completa, mesmo com o fatiamento.
# Out:
# A convidada de honra é Fran
# ['Zé', 'Mané', 'Ana']
# O primeiro convidado é Zé e o último convidado é Franz
# ['Zé', 'Mané', 'Ana', 'Fran', 'João', 'Franz']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# Armazenando e mostrando informações atraves do índice
#
# ---

# %%
# Método index(valor procurado, a partir de qual índice, e até qual índice)
# noivo.index('Fran' , 3 )
id = noivo.index('Fran') # Guadando o indice da Fran em uma variável.

# %%
# Qual é o imc da convidada Fran
print(f'O IMC da Fran é {(massas[id]/alturas[id]**2):.2f}')
# Out:
# O IMC da Fran é 17.26

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('Consulta da lista de convidados do noivo')
convidado = str(input('Digite o nome do convidado: ')) #Guandando o nome do convidado
convidado = convidado.capitalize() #Transformando a primeira palavra em maiúsculo, para não dar erro na consulta
if convidado in noivo:
    print(f'{convidado} está na lista de convidados.') #Verificando se consta na lista
    cx = True
    idx = noivo.index(f'{convidado}') #Procurando o nome e guardando o indice dele
    print(f'O IMC de {convidado} {(massas[idx]/alturas[idx]**2):.2f}') #Calculo de IMC.

else:
    print(f'Desculpe, {convidado} não está na lista de convidados.') #Caso não esteja, exibir tal mensagem
    cx = False
# Out:
# Consulta da lista de convidados do noivo
# Digite o nome do convidado: ze
# Desculpe, Ze não está na lista de convidados.

# %% [markdown]
# ## Adicionar itens na lista

# %% [markdown]
# ### Pesquisas

# %%
# Substituindo itens na lista atraves do indice:
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:4] = ["blackcurrant", "watermelon"] # Para acidinoar 2 itens nas poisições indicadas
print(thislist) # os elementos que existiam nos indices 1,2 e 3 foram substituidos
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'kiwi', 'mango']

# %%
# Adicionando item com append, colcoa ele na ultima posição da lista sempre!
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)

# %%
# .insert
# Adicionando item determinando a posição de acordo com o indice
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
# .extend
# Unindo 2 listas
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)

# %% [markdown]
# ### Prof.

# %%
# Adicionando elementos em uma lista qualquer com o método  append() por padrão este método insero o valor desejado em uma ista existente ne última posição
lista_vazia = [] # Criando uma nova lista vazia
lista_vazia.append('Joana') # Adicionando/atribuindo um nome

# %%
# Adiciona no último lugar da lista
# Adicionando elementos em uma lista qualquer com o método append() por padrão este método insero o valor desejado em uma lista existente na última posição
lista_vazia = [] # cria uma lista vazia com o nome lista vazia e apaga todos os elementos de qualquer objeto com o mesmo nome
print(lista_vazia) # imprime uma lista vazia que já existe
lista_vazia.append('Joana') # adiciona Joana na última posição de uma lista que já exista
lista_vazia.append('Douglas')
lista_vazia.append('Eduardo')
lista_vazia.append('Ester')
lista_vazia.append('Daniela')
lista_vazia.append('Pedro')
lista_vazia.append('Maria')
print(lista_vazia) # imprime o status atual da lista vazia
fam = lista_vazia
print(lista_vazia)
print(fam)
# Out:
# []
# ['Joana', 'Douglas', 'Eduardo', 'Ester', 'Daniela', 'Pedro', 'Maria']
# ['Joana', 'Douglas', 'Eduardo', 'Ester', 'Daniela', 'Pedro', 'Maria']
# ['Joana', 'Douglas', 'Eduardo', 'Ester', 'Daniela', 'Pedro', 'Maria']

# %%
#Insere diretamente na posição de indice escolhida
fam.insert(3, 'Tobias') # Insere o elemento (Tobias) no indice 3 (Ester), sem apagar o indice anterior (Ester), apenas "jogando"/deslocando pro lado
print(fam)
# Out:
# ['Joana', 'Douglas', 'Eduardo', 'Tobias', 'Ester', 'Daniela', 'Pedro', 'Maria']

# %%
# Insere substituindo o anterior
fam[3] = 'Raimundo' # Atribuição direta insere um novo elemento substituindo o anterior se houver
print(fam)
# Out:
# ['Joana', 'Douglas', 'Eduardo', 'Raimundo', 'Ester', 'Daniela', 'Pedro', 'Maria']

# %% [markdown]
# ### RESUMO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# .append adiciona no último lugar da lista, SEMPRE!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Excluir elementos

# %%
# Excluindo elementos de uma lista
fam.pop() # excluiu pelo indice, por padrão exclui o último elemento se não informarmos o índice
print(fam)
# Out:
# ['Joana', 'Douglas', 'Eduardo', 'Raimundo', 'Ester', 'Daniela', 'Pedro']

# %%
# Excluindo atribuindo o indice/posição
fam.pop(0) #Indice 0 é a Joana
print(fam)
# Out:
# ['Douglas', 'Eduardo', 'Raimundo', 'Ester', 'Daniela', 'Pedro']

# %%
# Excluindo raimundo da lista fam pelo metodo remove
fam.remove('Raimundo')
print(fam)
# Out:
# ['Douglas', 'Eduardo', 'Ester', 'Daniela', 'Pedro']

# %%
# Excluindo raimundo da lista fam pelo metodo remove
# fam.remove(1)
# print(fam)
# REMOVE APENAS PELO NOME DO ELEMENTO, E NÃO PELO INDICE
# Out:
# ['Douglas', 'Ester', 'Daniela', 'Pedro']

# %% [markdown]
# ### Praticando

# %% [markdown]
# Desafio 1': Crie um programa que receba do usuário um nome e caso esse nome esteja na lista guarde seu índice em uma variável e a utilize para buscar massa e altura correspondente, bem como calcular seu imc e após tudo isso informar o usuário, caso o nome não esteja na lista retorne uma mensagem informando o usuário

# %%
idades = [41, 47, 46, 28, 17, 50]
massas = [86, 74, 52, 47, 90, 110]
alturas = [1.68, 1.74, 1.65, 1.65, 1.80, 1.97]
noivo = ['Zé','Mané','Ana','Fran','João','Franz'] # Cria o banco de dados com os nomes dos convidados do noivo
nome = input('Informe o nome que deseja consultar: ') #recebendo o nome do usuário
nome = nome.capitalize() #Deixo o nome que o usuário digitou com a primeira letra em caixa alta e as demais em caixa baixa
if nome in noivo: # se o nome que o usuário digitou estiver no banco de dados faça algo
  id2 = noivo.index(nome) # recebendo o argumento nome e procurando o seu índice já sabendo que ele está na lista exatmente com a mesma grafia
  imc = massas[id2]/alturas[id2]**2 # calculando o imc já sabendo a posição que deve busta em cada lista (massas e alturas)
  print(f'{nome} tem {massas[id2]} kg, {alturas[id2]} metros e seu imc é: {imc:.1f}') # Mostrando o nome digitado e seus respectivos massa, altura e imc
else:
  print(f'Desculpe, {nome} não está na lista, por favor reinicie o programa para consultar outro nome')
# Out:
# Informe o nome que deseja consultar: Mané
# Mané tem 74 kg, 1.74 metros e seu imc é: 24.4

# %% [markdown]
# # Range

# %% [markdown]
# ![image.png](data:image/png;base64,...)
